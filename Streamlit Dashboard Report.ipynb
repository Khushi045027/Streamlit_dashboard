# %% [markdown]
# In DEV-P I Project, the dataset I chose to to perform Data Manipulation and Data Visualization was  focusing on YouTube's video views, subscribers, and viewership trends across different channels. It utilized various techniques, including data collection from VidIQ, statistical analysis, and sorting methods.
# Key Findings of that project were:
# a) The total dataset encompassed a significant amount of data: 2,876,575 videos, 197,905,672,000 views, and 3,649,900,000 subscribers.
# b)Central tendency, variance, correlation, time series analysis, and statistical analysis were employed to uncover key insights.
# c)The report aimed to provide a comprehensive understanding of YouTube channel dynamics in India and offer actionable insights for content creators and marketers.
#
# Now, in DEV-P II project, I tried to connect my project with my previous project by chosing a dataset that was also related with YouTube. This report section explores the view count trends, likes and comments counts for YouTube Shorts across the years 2021, 2022, and 2023, aiming to identify key patterns and offer actionable recommendations for content optimization.
#
# Objectives:
#
# 1. Analyze the evolution of view counts for YouTube Shorts over time.
# 2. Identify potential factors influencing view count trends and patterns.
# 3. Provide data-driven insights and recommendations to maximize view count potential for future Shorts content.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# # 1. VIEW COUNT OVER TIME(YEARS)
#
# THE GRAPHS HERE REPRESENTS THAT VIEW COUNT WAS ABOUT 555.8366M IN YEAR 2021, AROUND 350.916M IN YEAR 2022 AND AND NEARLY 746.7175M IN YEAR 2023
# IT CAN BE OBSERVED THAT THERE WAS A FALL IN AVERAGE VIEWS FROM 121.388M IN 2021 TO 111.143M IN 2022 WHICH GREW TO 368.8035M IN 2023.
#
# Observations:
#
# 1. Overall Growth: The total view count appears to have grown steadily across all three years, suggesting increasing viewership and engagement with YouTube Shorts.
# 2. Yearly Fluctuations: While the overall trend is positive, there might be noticeable fluctuations in view counts within each year. Specific months or quarters might display higher or lower viewership compared to others.
# 3. Outliers: Certain Shorts within the dataset might stand out with significantly higher or lower view counts compared to the average. These outliers warrant further investigation to understand potential contributing factors.
#
# Interpretations:
#
# 1. The consistent growth in overall view count indicates the rising popularity and potential of the YouTube Shorts format. This bodes well for creators and brands looking to tap into this growing audience.
# 2. Yearly fluctuations could be attributed to various factors, such as seasonal trends, platform algorithm changes, content shifts, or external events. Analyzing these factors in conjunction with view count data can provide valuable insights for optimizing content timing and strategies.
#
# Managerial Implications:
#
# 1. Focus on evergreen content: Create Shorts that address timeless topics and trends to maintain consistent viewership throughout the year.
# 2. Monitor platform updates and audience preferences: Stay informed about algorithm changes and evolving audience interests to adapt content strategies accordingly.
# 3. Analyze high-performing content: Identify the key elements of successful Shorts and incorporate those elements into your own content creation process.
# 4. Leverage seasonal trends: Plan and publish Shorts strategically to capitalize on periods of increased viewership within your target audience.High-performing outliers can offer valuable lessons for replicating success. Analyzing their content themes, formats, publication times, and audience demographics can reveal best practices for maximizing viewership.
# 5. Experiment with different formats and lengths: Test various Shorts formats and durations to discover what resonates best with your viewers and maximizes view count potential.

# %% [markdown]
# # LIKE COUNT OVER TIME
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
#
# This section explores the relationship between like count and view count for YouTube Shorts across 2021, 2022, and 2023, as revealed in the line graph you provided. In 2021, the likes count to around 16M, 15M in 2022, and 13M in 2023.I have performed this to assess the overall relationship between like count and view count across the three years.
#
#
# Observations:
#
# 1. General Trend: The line graph likely shows a positive correlation between like count and view count, suggesting that Shorts with higher view counts tend to receive more likes as well. However, the strength and nature of this correlation can be further analyzed.
# 2. Year-wise Differences: There might be variations in the slope and position of the line for each year, indicating potential shifts in the relationship between likes and views across the three years. For example, 2023 might have a steeper slope than 2021 and 2022, suggesting a stronger correlation between views and likes in the most recent year.
# 3. Outlier Potential: Depending on the scale and granularity of the graph, there might be individual data points significantly above or below the general trendline for each year. These outliers could represent Shorts that garnered exceptionally high or low likes despite their view counts, potentially due to unique content elements or other factors.
#
#
# Interpretations:
#
# 1. The positive correlation between like count and view count suggests that high-quality, engaging content tends to attract both views and likes. This emphasizes the importance of creating content that resonates with your target audience and drives viewer engagement.
# 2. Year-wise differences in the line's slope might indicate shifts in audience preferences or platform algorithms. Understanding these shifts can help you adapt your content strategies accordingly. For example, if viewers in 2023 seem to be more likely to like Shorts with higher view counts, focus on creating content that captures their attention and keeps them engaged throughout the video.
# 3. Analyzing outliers can reveal valuable insights into content elements that drive exceptional engagement. Investigating the themes, formats, and publication timing of these outliers within each year might provide best practices for replicating their success and maximizing both likes and views for your own Shorts.
#
#
# Managerial Implications:
#
# 1. Focus on quality and engagement: Prioritize creating high-quality, engaging Shorts that resonate with your target audience to drive both views and likes.
# 2. Monitor year-wise trends: Stay informed about evolving viewer preferences and platform algorithms, and adapt your content strategies accordingly.
# 3. Leverage the power of virality: Consider incorporating elements that have the potential to go viral, such as catchy trends, challenges, or humor, to boost both views and likes.
# 4. Learn from outliers: Analyze the content, format, and publication timing of high-performing Shorts within each year. Incorporate these insights into your own content creation process to potentially replicate their success and maximize engagement.
# 5. Track additional metrics: While likes and views are important, consider analyzing other performance indicators like comments, shares, and audience retention to gain a holistic understanding of what content resonates best with your viewers.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# # COMMENT COUNT OVER VIEW TIME
#
# This section explores the relationship between comment count and view count for YouTube Shorts across the years 2021, 2022, and 2023, as revealed in the graph you provided. In 2021, the comment count is 24k, 41.5k and 47.76k in years 2022and 2023, respectively. This shows the overall relationship between comment count and view count across the three years.
#
#
# Observations:
#
# 1. General Trend: The graph likely shows a positive correlation between comment count and view count, suggesting that Shorts with higher view counts tend to receive more comments as well. However, the strength and nature of this correlation can be further analyzed.
# 2. Year-wise Differences: There might be variations in the slope and position of the line for each year, indicating potential shifts in the relationship between comments and views across the three years. For example, 2023 might have a steeper slope than 2021 and 2022, suggesting a stronger correlation between views and comments in the most recent year.
# 3. Outlier Potential: Depending on the scale and granularity of the graph, there might be individual data points significantly above or below the general trendline for each year. These outliers could represent Shorts that garnered exceptionally high or low comments despite their view counts, potentially due to unique content elements or other factors.
#
#
# Interpretations:
#
# 1. The positive correlation between comment count and view count suggests that highly engaging and thought-provoking content tends to spark conversations and elicit comments from viewers. This reinforces the importance of creating content that goes beyond simply entertaining and prompts viewers to share their thoughts and opinions.
# 2. Year-wise differences in the line's slope might indicate shifts in audience preferences or platform algorithms. Understanding these shifts can help you adapt your content strategies accordingly. For example, if viewers in 2023 seem to be more likely to comment on Shorts with higher view counts, focus on creating content that encourages conversation and interaction.
# 3. Analyzing outliers can reveal valuable insights into content elements that drive exceptional engagement. Investigating the themes, formats, and publication timing of these outliers within each year might provide best practices for replicating their success and maximizing both comments and views for your own Shorts.
#
#
# Managerial Implications:
#
# 1. Focus on engagement and interaction: Create content that prompts conversation and encourages viewers to leave comments. Ask questions, pose thought-provoking challenges, or invite viewers to share their own experiences related to your video's theme.
# 2. Monitor year-wise trends: Stay informed about evolving audience preferences and platform algorithms, and adapt your content strategies accordingly. If viewers are increasingly commenting on specific types of Shorts, consider incorporating those elements into your own content.
# 3. Leverage community building: Respond to comments and participate in conversations with your viewers. This fosters a sense of community and encourages further engagement.
# 4. Learn from outliers: Analyze the content, format, and publication timing of high-performing Shorts within each year. Incorporate these insights into your own content creation process to potentially replicate their success and maximize comments and views.
# 5. Track additional metrics: While comments and views are important, consider analyzing other performance indicators like shares, likes, and audience retention to gain a holistic understanding of what content resonates best with your viewers.

# %% [markdown]
# ![image.png](attachment:image.png)
# # YEAR WISE DISTRIBUTION OF VIEWS
#
#
# This section explores the year-wise distribution of view counts for YouTube Shorts, aiming to identify key trends in viewership patterns across 2021, 2022, and 2023. In year 2021 its about 4.9%, and in years 2022 & 2023, its 29.4% and 65.7%, respectively.  By analyzing how view counts are distributed across each year, we can uncover valuable insights for optimizing content strategies and maximizing viewership potential factors influencing yearly view count trends..
#
#
# Observations:
#
# 1. Dominant Year: Based on the image, 2023 appears to have the largest share of total view counts represented by the largest segment of the graph (assuming it's a pie or donut chart). This suggests a potential increase in overall viewership and engagement with YouTube Shorts in the most recent year.
# 2. Shifting Distribution: While 2023 dominates, the remaining segments for 2021 and 2022 indicate view counts were still significant in those years. However, the distribution suggests a potential shift in viewership towards 2023.
# 3.  Outliers: Depending on the scale and granularity of the chart, there might be smaller segments representing individual Shorts with exceptionally high or low view counts. These outliers could offer valuable insights into specific content strategies or trends that drove those viewership patterns.
#
#
# Interpretations:
#
# 1. The dominance of 2023 in the view count distribution might reflect the growing popularity and reach of YouTube Shorts as a format. It could also indicate factors like platform algorithm changes or evolving audience preferences favoring more recent content.
# 2. The observed shift in viewership towards 2023 highlights the importance of staying updated with current trends and adapting content strategies accordingly. Focusing on content themes and formats that resonate with the present audience could be key to maximizing viewership.
# 3. Analyzing potential outliers, if any, can reveal valuable lessons about what content resonates with viewers and drives high engagement. Understanding the themes, formats, and publication timing of these outliers can inform your own content creation process for maximizing viewership potential.
#
#
# Managerial Implications:
#
# 1. Prioritize content aligned with current trends: Analyze what types of content are performing well in 2023 and incorporate similar elements into your own Shorts creation.
# 2. Monitor platform updates and audience preferences: Stay informed about changes in the YouTube algorithm and audience interests to adapt your content strategies accordingly.
# 3. Leverage the "freshness factor": Consider prioritizing publishing new Shorts content regularly to capitalize on the potential preference for recent content on the platform.
# 4. Experiment with different formats and lengths: While 2023 dominates, the presence of view counts for 2021 and 2022 suggests other formats and lengths can still attract viewers. Test various approaches to discover what resonates best with your target audience.
# 5. Analyze standout outliers: If present, delve deeper into the content elements, publication timing, and audience demographics of exceptionally high-performing Shorts. Incorporate these insights into your own content creation to potentially replicate their success.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# # DURATION VS VIEW COUNT
#
# This section explores the year-wise distribution of view counts for YouTube Shorts, aiming to identify key trends in viewership patterns across 2021, 2022, and 2023. In this representaion, I have taken the duration in seconds of the shorts in y axis and the years in x axis. This resulted in describing how much likes a shorts video of how much seconds got, in each year. In 2021, shorts with duration 23 seconds have highest like count whereas shrts with duration of 38 seconds got lowest likes count in that year. Similarly, for other two years can be seen in this representation
#
#
# Observations:
#
# 1. Dominant Year: Based on the image, 2023 appears to have the largest share of total view counts represented by the largest segment of the graph (assuming it's a pie or donut chart). This suggests a potential increase in overall viewership and engagement with YouTube Shorts in the most recent year.
# 2. Shifting Distribution: While 2023 dominates, the remaining segments for 2021 and 2022 indicate view counts were still significant in those years. However, the distribution suggests a potential shift in viewership towards 2023.
# 3. Potential Outliers: Depending on the scale and granularity of the chart, there might be smaller segments representing individual Shorts with exceptionally high or low view counts. These outliers could offer valuable insights into specific content strategies or trends that drove those viewership patterns.
#
#
# Interpretations:
#
# 1. The dominance of 2023 in the view count distribution might reflect the growing popularity and reach of YouTube Shorts as a format. It could also indicate factors like platform algorithm changes or evolving audience preferences favoring more recent content.
# 2. The observed shift in viewership towards 2023 highlights the importance of staying updated with current trends and adapting content strategies accordingly. Focusing on content themes and formats that resonate with the present audience could be key to maximizing viewership.
# 3. Analyzing potential outliers, if any, can reveal valuable lessons about what content resonates with viewers and drives high engagement. Understanding the themes, formats, and publication timing of these outliers can inform your own content creation process for maximizing viewership potential.
#
#
# Managerial Implications:
#
# 1. Prioritize content aligned with current trends: Analyze what types of content are performing well in 2023 and incorporate similar elements into your own Shorts creation.
# 2. Monitor platform updates and audience preferences: Stay informed about changes in the YouTube algorithm and audience interests to adapt your content strategies accordingly.
# 3. Leverage the "freshness factor": Consider prioritizing publishing new Shorts content regularly to capitalize on the potential preference for recent content on the platform.
# 4. Experiment with different formats and lengths: While 2023 dominates, the presence of view counts for 2021 and 2022 suggests other formats and lengths can still attract viewers. Test various approaches to discover what resonates best with your target audience.
# 5. Analyze standout outliers: If present, delve deeper into the content elements, publication timing, and audience demographics of exceptionally high-performing Shorts. Incorporate these insights into your own content creation to potentially replicate their success.

# %% [markdown]
# ![image.png](attachment:image.png)
# # DISTRIBUTION OF VIEW COUNT EACH YEAR
#
# This section explores the year-wise distribution of views for YouTube Shorts across 2021, 2022, and 2023, as revealed in the donut chart you provided. By analyzing the relative sizes of each year's segment, we can uncover key trends in viewership patterns and identify actionable insights for optimizing content strategies.
#
#
# Observations:
#
# 1. Dominant Year: As expected, 2023 stands out with the largest segment, representing the highest share of total view counts. This reinforces the previous observation of increased viewership and engagement with YouTube Shorts in the most recent year.
# 2. Shifting Shares: While 2023 dominates, the remaining segments for 2021 and 2022 are still present, indicating significant viewership for those years as well. However, the proportions clearly shift towards 2023, highlighting a potential trend in viewership preference.
# 3. Segment Variations: Within each year's segment, there are likely variations in the sizes of individual slices. This suggests that specific Shorts within each year garnered significantly higher or lower view counts compared to others. Analyzing these outliers could reveal valuable insights into successful content strategies.
#
#
# Interpretations:
#
# 1. The substantial size of the 2023 segment confirms the rising popularity and reach of YouTube Shorts as a format. This trend could be attributed to various factors, including platform algorithm changes, evolving audience preferences, or the increasing adoption of the format by creators and brands.
# 2. The shift in viewership towards 2023 emphasizes the importance of staying relevant and adapting content strategies to current trends. Focusing on themes, formats, and styles that resonate with the present audience can significantly impact viewership potential.
# 3. Variations in segment sizes within each year indicate that specific content elements contribute to higher viewership. Analyzing high-performing outliers within each year can reveal best practices for maximizing engagement, such as focusing on specific themes, formats, or publication timing.
#
#
# Managerial Implications:
#
# 1. Align content with current trends: Analyze popular content themes and formats in 2023 and incorporate similar elements into your own Shorts creation.
# 2. Stay informed and adapt: Monitor platform updates and audience preferences to adjust your content strategies accordingly.
# 3. Capitalize on freshness: Consider publishing new Shorts content regularly to potentially benefit from the observed preference for recent content.
# 4. Experiment strategically: While 2023 dominates, the presence of viewership in 2021 and 2022 suggests other approaches can still work. Test various formats and lengths to discover what resonates best with your target audience.
# 5. Learn from outliers: Analyze the content elements, publication timing, and audience demographics of high-performing Shorts within each year. Incorporate these insights into your own content creation to potentially replicate their success.

# %% [markdown]
# ![image.png](attachment:image.png)
# # CORRELATION HEATMAP
#
# This section explores the relationship between duration and like count for YouTube Shorts across the years 2021, 2022, and 2023, as revealed in the scatter plot you provided. By analyzing the distribution and trends of data points on the chart, we can uncover potential correlations between video length and viewer engagement and identify effective content strategies for maximizing likes.
#
#
# Observations:
#
# 1. Scattered Distribution: The data points appear scattered across the chart, suggesting that there's no single, strong correlation between video duration and like count. However, patterns and trends might emerge upon closer examination.
# 2. Year-wise Clusters: While scattered, data points seem to form distinct clusters for each year, indicating potential differences in the duration-like count relationship across the three years. 2023 might have a different cluster pattern compared to 2021 and 2022.
# 3. Potential Outliers: There might be individual data points significantly above or below the general clusters within each year. These outliers could represent videos that received exceptionally high or low like counts despite their duration, potentially due to unique content elements or other factors.
#
#
# Interpretations:
#
# 1. The lack of a clear linear correlation suggests that various factors beyond video length contribute to like count. Content quality, topic relevance, audience demographics, and publication timing likely play a significant role in viewer engagement.
# 2. Year-wise clusters may indicate shifts in audience preferences regarding video length for optimal engagement. Understanding these shifts can help you tailor your content accordingly. For example, if viewers in 2023 seem to favor shorter videos with higher like counts, consider adjusting your average length to potentially maximize engagement.
# 3. Analyzing outliers can reveal valuable insights into content elements that drive exceptional engagement. Investigating the themes, formats, and publication timing of these outliers within each year might provide best practices for replicating their success and maximizing like potential for your own Shorts.
#
#
# Managerial Implications:
#
# 1. Focus on quality over length: While duration might not be the sole factor, prioritize creating high-quality, engaging content that resonates with your target audience.
# 2. Monitor year-wise trends: Stay informed about evolving audience preferences regarding video length for YouTube Shorts within your target demographic. Adapt your content length strategies based on these trends.
# 3. Experiment with diverse lengths: Don't limit yourself to a single duration. Test various video lengths within your niche to discover what resonates best with your viewers and maximizes like potential.
# 4. Learn from outliers: Analyze the content, format, and publication timing of exceptionally high-performing Shorts within each year. Incorporate these insights into your own content creation process to potentially emulate their success and drive higher like counts.
# 5. Consider additional factors: Remember that like count is just one metric of engagement. Analyze other performance indicators like views, comments, and shares to gain a holistic understanding of what content resonates best with your audience.

# %% [markdown]
# # CONCLUSIONS, LIMITATIONS, AND RECOMMENDATIONS
#
#
# Recommendations:
#
# 1. Focus on quality and engagement: Prioritize creating high-quality Shorts that resonate with your target audience and stimulate conversations. Ask questions, incorporate trending elements, and encourage viewer interaction.
# 2. Stay informed and adapt: Monitor year-wise trends in audience preferences and platform algorithms. Adjust your content strategies and formats based on these evolving behaviors.
# 3. Learn from outliers: Analyze the content, format, and publication timing of high-performing outliers within each metric and category. Adapt these elements into your own Shorts to potentially replicate their success.
# 4. Track additional metrics: While views, likes, and comments are valuable, consider tracking other performance indicators like shares, audience retention, and demographics to gain a comprehensive understanding of your content's impact.
# 5. Seek further data: If possible, acquire access to more comprehensive data sets to allow for deeper analysis and identification of additional insights and trends.
#
#
# Conclusions:
#
# 1. Engagement matters: Across all metrics analyzed (views, likes, comments), high-quality, engaging content emerged as the key driver of success for YouTube Shorts. Content that resonates with the target audience, sparks conversation, and encourages interaction tends to perform better.
# 2. Year-wise trends shift: Viewer preferences and platform algorithms evolve over time. Analyzing year-wise differences in data visualizations revealed changes in the relationship between video duration, likes, views, and comments. Staying informed about these trends is crucial for adapting content strategies and maximizing engagement.
# 3. Outliers offer valuable insights: Analyzing high-performing outliers across each metric can provide valuable best practices for replicating their success. Themes, formats, publication timing, and other elements of these outliers can be incorporated into your own content creation process.
#
#
# Limitations:
#
# 1. Data availability: The analyses were based on the specific data sets and visualizations provided. Access to more comprehensive data, including audience demographics, content categories, and specific video elements, could have yielded even deeper insights.
# 2. Correlation vs. causation: While trends and relationships were identified, the analyses cannot definitively establish causation. Factors beyond the analyzed metrics might also influence performance.
# 3. Visualizations provided: The accuracy of the conclusions is limited by the clarity and completeness of the provided visualizations. Additional information or clearer representations could potentially reveal further nuances.
